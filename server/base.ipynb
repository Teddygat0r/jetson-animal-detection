# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\charl\anaconda3\lib\site-packages (2.13.0)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\charl\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: matplotlib in c:\users\charl\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: packaging in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (22.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: setuptools in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (65.6.3)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.23.5)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\charl\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\charl\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\charl\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\charl\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in c:\users\charl\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.14)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\charl\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\charl\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\charl\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\charl\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\charl\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\charl\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\charl\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\charl\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\charl\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: python_version, tensorflow-gpu
#   Running setup.py install for tensorflow-gpu: started
#   Running setup.py install for tensorflow-gpu: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\charl\AppData\Local\Temp\pip-install-rkrpzltt\tensorflow-gpu_61de40a09e424e3e8e5e7eb7a0c0c90d\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   error: subprocess-exited-with-error
#
#   Running setup.py install for tensorflow-gpu did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\charl\AppData\Local\Temp\pip-install-rkrpzltt\tensorflow-gpu_61de40a09e424e3e8e5e7eb7a0c0c90d\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU')) 

# Check if a GPU is available
if tf.config.list_physical_devices('GPU'):
    print('GPU is available')
else:
    print('GPU is not available')
# Out:
# []
# GPU is not available
